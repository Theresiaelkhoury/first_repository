# %% [markdown]
# # Segmenting and Clustering Neighborhoods in Toronto

# %% [markdown]
# ## import the needed Library and read the zip code url and table, also install the library for the map, geo and kmean if not installed

# %%
## import the needed Library
import pandas as pd
import numpy as np
import urllib
from bs4 import BeautifulSoup
import json # library to handle JSON files

# !conda install -c conda-forge geopy --yes # uncomment this line if you haven't completed the Foursquare API lab
from geopy.geocoders import Nominatim # convert an address into latitude and longitude values

import requests # library to handle requests
from pandas.io.json import json_normalize # tranform JSON file into a pandas dataframe

# Matplotlib and associated plotting modules
import matplotlib.cm as cm
import matplotlib.colors as colors

# import k-means from clustering stage
from sklearn.cluster import KMeans

# !conda install -c conda-forge folium=0.5.0 --yes # uncomment this line if you haven't completed the Foursquare API lab
import folium # map rendering library
print('package installed')
# Out:
# Fetching package metadata .............
# Solving package specifications: .
#
# # All requested packages already installed.
# # packages in environment at /opt/conda/envs/DSX-Python35:
# #
# geopy                     1.18.1                     py_0    conda-forge
# Fetching package metadata .............
# Solving package specifications: .
#
# # All requested packages already installed.
# # packages in environment at /opt/conda/envs/DSX-Python35:
# #
# folium                    0.5.0                      py_0    conda-forge
# package installed

# %% [markdown]
# ## read the wikipedia data

# %%
torontoWikiUrl = 'https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M'
torontoResponse = urllib.request.urlopen(torontoWikiUrl)
totontoData = torontoResponse.read().decode('utf-8')
zipCodeHtml= BeautifulSoup(totontoData, 'html.parser')
zipCodeTable = zipCodeHtml.find('table', class_='wikitable sortable')
zipCodeList=[]
for tr in zipCodeTable.find_all('tr'):
    trow = []
    for td in tr.find_all('td'):
        trow.append(td.text.strip('\n'))
    zipCodeList.append(trow)

# %% [markdown]
# ## construct the dataframe from html response
# ## The dataframe will consist of three columns: PostalCode, Borough, and Neighborhood

# %%
zipCodeDF = pd.DataFrame(zipCodeList, columns = ['PostalCode', 'Borough', 'Neighborhood'])
## remove the header html tag
zipCodeDF = zipCodeDF[1:]
zipCodeDF
# Out:
#     PostalCode           Borough  \
# 1          M1A      Not assigned
# 2          M2A      Not assigned
# 3          M3A        North York
# 4          M4A        North York
# 5          M5A  Downtown Toronto
# 6          M5A  Downtown Toronto
# 7          M6A        North York
# 8          M6A        North York
# 9          M7A      Queen's Park
# 10         M8A      Not assigned
# 11         M9A         Etobicoke
# 12         M1B       Scarborough
# 13         M1B       Scarborough
# 14         M2B      Not assigned
# 15         M3B        North York
# 16         M4B         East York
# 17         M4B         East York
# 18         M5B  Downtown Toronto
# 19         M5B  Downtown Toronto
# 20         M6B        North York
# 21         M7B      Not assigned
# 22         M8B      Not assigned
# 23         M9B         Etobicoke
# 24         M9B         Etobicoke
# 25         M9B         Etobicoke
# 26         M9B         Etobicoke
# 27         M9B         Etobicoke
# 28         M1C       Scarborough
# 29         M1C       Scarborough
# 30         M1C       Scarborough
# ..         ...               ...
# 260        M9X      Not assigned
# 261        M1Y      Not assigned
# 262        M2Y      Not assigned
# 263        M3Y      Not assigned
# 264        M4Y  Downtown Toronto
# 265        M5Y      Not assigned
# 266        M6Y      Not assigned
# 267        M7Y      East Toronto
# 268        M8Y         Etobicoke
# 269        M8Y         Etobicoke
# 270        M8Y         Etobicoke
# 271        M8Y         Etobicoke
# 272        M8Y         Etobicoke
# 273        M8Y         Etobicoke
# 274        M8Y         Etobicoke
# 275        M8Y         Etobicoke
# 276        M9Y      Not assigned
# 277        M1Z      Not assigned
# 278        M2Z      Not assigned
# 279        M3Z      Not assigned
# 280        M4Z      Not assigned
# 281        M5Z      Not assigned
# 282        M6Z      Not assigned
# 283        M7Z      Not assigned
# 284        M8Z         Etobicoke
# 285        M8Z         Etobicoke
# 286        M8Z         Etobicoke
# 287        M8Z         Etobicoke
# 288        M8Z         Etobicoke
# 289        M9Z      Not assigned
#
#                                           Neighborhood
# 1                                         Not assigned
# 2                                         Not assigned
# 3                                            Parkwoods
# 4                                     Victoria Village
# 5                                         Harbourfront
# 6                                          Regent Park
# 7                                     Lawrence Heights
# 8                                       Lawrence Manor
# 9                                         Not assigned
# 10                                        Not assigned
# 11                                    Islington Avenue
# 12                                               Rouge
# 13                                             Malvern
# 14                                        Not assigned
# 15                                     Don Mills North
# 16                                    Woodbine Gardens
# 17                                       Parkview Hill
# 18                                             Ryerson
# 19                                     Garden District
# 20                                           Glencairn
# 21                                        Not assigned
# 22                                        Not assigned
# 23                                          Cloverdale
# 24                                           Islington
# 25                                        Martin Grove
# 26                                    Princess Gardens
# 27                                     West Deane Park
# 28                                      Highland Creek
# 29                                          Rouge Hill
# 30                                          Port Union
# ..                                                 ...
# 260                                       Not assigned
# 261                                       Not assigned
# 262                                       Not assigned
# 263                                       Not assigned
# 264                               Church and Wellesley
# 265                                       Not assigned
# 266                                       Not assigned
# 267  Business Reply Mail Processing Centre 969 Eastern
# 268                                         Humber Bay
# 269                                   King's Mill Park
# 270                           Kingsway Park South East
# 271                                          Mimico NE
# 272                                     Old Mill South
# 273                                 The Queensway East
# 274                              Royal York South East
# 275                                           Sunnylea
# 276                                       Not assigned
# 277                                       Not assigned
# 278                                       Not assigned
# 279                                       Not assigned
# 280                                       Not assigned
# 281                                       Not assigned
# 282                                       Not assigned
# 283                                       Not assigned
# 284                           Kingsway Park South West
# 285                                          Mimico NW
# 286                                 The Queensway West
# 287                              Royal York South West
# 288                                     South of Bloor
# 289                                       Not assigned
#
# [289 rows x 3 columns]

# %% [markdown]
# ## Only process the cells that have an assigned borough. Ignore cells with a borough that is Not assigned.

# %%
zipCodeDF_borough = zipCodeDF[zipCodeDF.Borough != 'Not assigned']  
zipCodeDF_borough
# Out:
#     PostalCode           Borough  \
# 3          M3A        North York
# 4          M4A        North York
# 5          M5A  Downtown Toronto
# 6          M5A  Downtown Toronto
# 7          M6A        North York
# 8          M6A        North York
# 9          M7A      Queen's Park
# 11         M9A         Etobicoke
# 12         M1B       Scarborough
# 13         M1B       Scarborough
# 15         M3B        North York
# 16         M4B         East York
# 17         M4B         East York
# 18         M5B  Downtown Toronto
# 19         M5B  Downtown Toronto
# 20         M6B        North York
# 23         M9B         Etobicoke
# 24         M9B         Etobicoke
# 25         M9B         Etobicoke
# 26         M9B         Etobicoke
# 27         M9B         Etobicoke
# 28         M1C       Scarborough
# 29         M1C       Scarborough
# 30         M1C       Scarborough
# 32         M3C        North York
# 33         M3C        North York
# 34         M4C         East York
# 35         M5C  Downtown Toronto
# 36         M6C              York
# 39         M9C         Etobicoke
# ..         ...               ...
# 237        M1W       Scarborough
# 238        M1W       Scarborough
# 241        M4W  Downtown Toronto
# 242        M5W  Downtown Toronto
# 245        M8W         Etobicoke
# 246        M8W         Etobicoke
# 247        M9W         Etobicoke
# 248        M1X       Scarborough
# 251        M4X  Downtown Toronto
# 252        M4X  Downtown Toronto
# 253        M5X  Downtown Toronto
# 254        M5X  Downtown Toronto
# 257        M8X         Etobicoke
# 258        M8X         Etobicoke
# 259        M8X         Etobicoke
# 264        M4Y  Downtown Toronto
# 267        M7Y      East Toronto
# 268        M8Y         Etobicoke
# 269        M8Y         Etobicoke
# 270        M8Y         Etobicoke
# 271        M8Y         Etobicoke
# 272        M8Y         Etobicoke
# 273        M8Y         Etobicoke
# 274        M8Y         Etobicoke
# 275        M8Y         Etobicoke
# 284        M8Z         Etobicoke
# 285        M8Z         Etobicoke
# 286        M8Z         Etobicoke
# 287        M8Z         Etobicoke
# 288        M8Z         Etobicoke
#
#                                           Neighborhood
# 3                                            Parkwoods
# 4                                     Victoria Village
# 5                                         Harbourfront
# 6                                          Regent Park
# 7                                     Lawrence Heights
# 8                                       Lawrence Manor
# 9                                         Not assigned
# 11                                    Islington Avenue
# 12                                               Rouge
# 13                                             Malvern
# 15                                     Don Mills North
# 16                                    Woodbine Gardens
# 17                                       Parkview Hill
# 18                                             Ryerson
# 19                                     Garden District
# 20                                           Glencairn
# 23                                          Cloverdale
# 24                                           Islington
# 25                                        Martin Grove
# 26                                    Princess Gardens
# 27                                     West Deane Park
# 28                                      Highland Creek
# 29                                          Rouge Hill
# 30                                          Port Union
# 32                                     Flemingdon Park
# 33                                     Don Mills South
# 34                                    Woodbine Heights
# 35                                      St. James Town
# 36                                  Humewood-Cedarvale
# 39                                   Bloordale Gardens
# ..                                                 ...
# 237                                    L'Amoreaux West
# 238                                       Steeles West
# 241                                           Rosedale
# 242                    Stn A PO Boxes 25 The Esplanade
# 245                                          Alderwood
# 246                                        Long Branch
# 247                                          Northwest
# 248                                        Upper Rouge
# 251                                        Cabbagetown
# 252                                     St. James Town
# 253                               First Canadian Place
# 254                                   Underground city
# 257                                       The Kingsway
# 258                                    Montgomery Road
# 259                                     Old Mill North
# 264                               Church and Wellesley
# 267  Business Reply Mail Processing Centre 969 Eastern
# 268                                         Humber Bay
# 269                                   King's Mill Park
# 270                           Kingsway Park South East
# 271                                          Mimico NE
# 272                                     Old Mill South
# 273                                 The Queensway East
# 274                              Royal York South East
# 275                                           Sunnylea
# 284                           Kingsway Park South West
# 285                                          Mimico NW
# 286                                 The Queensway West
# 287                              Royal York South West
# 288                                     South of Bloor
#
# [212 rows x 3 columns]

# %%
zipCodeDF_borough.describe()
# Out:
#        PostalCode    Borough Neighborhood
# count         212        212          212
# unique        103         11          210
# top           M8Y  Etobicoke    Runnymede
# freq            8         45            2

# %% [markdown]
# ## If a cell has a borough but a Not assigned neighborhood, then the neighborhood will be the same as the borough

# %%
zipCodeDF_borough.is_copy=False 
zipCodeDF_borough['Neighborhood'] = np.where(zipCodeDF_borough['Neighborhood'].values == 'Not assigned', 
                                                   zipCodeDF_borough['Borough'].values,
                                                   zipCodeDF_borough['Neighborhood'].values
                                            )
zipCodeDF_borough
# Out:
#     PostalCode           Borough  \
# 3          M3A        North York
# 4          M4A        North York
# 5          M5A  Downtown Toronto
# 6          M5A  Downtown Toronto
# 7          M6A        North York
# 8          M6A        North York
# 9          M7A      Queen's Park
# 11         M9A         Etobicoke
# 12         M1B       Scarborough
# 13         M1B       Scarborough
# 15         M3B        North York
# 16         M4B         East York
# 17         M4B         East York
# 18         M5B  Downtown Toronto
# 19         M5B  Downtown Toronto
# 20         M6B        North York
# 23         M9B         Etobicoke
# 24         M9B         Etobicoke
# 25         M9B         Etobicoke
# 26         M9B         Etobicoke
# 27         M9B         Etobicoke
# 28         M1C       Scarborough
# 29         M1C       Scarborough
# 30         M1C       Scarborough
# 32         M3C        North York
# 33         M3C        North York
# 34         M4C         East York
# 35         M5C  Downtown Toronto
# 36         M6C              York
# 39         M9C         Etobicoke
# ..         ...               ...
# 237        M1W       Scarborough
# 238        M1W       Scarborough
# 241        M4W  Downtown Toronto
# 242        M5W  Downtown Toronto
# 245        M8W         Etobicoke
# 246        M8W         Etobicoke
# 247        M9W         Etobicoke
# 248        M1X       Scarborough
# 251        M4X  Downtown Toronto
# 252        M4X  Downtown Toronto
# 253        M5X  Downtown Toronto
# 254        M5X  Downtown Toronto
# 257        M8X         Etobicoke
# 258        M8X         Etobicoke
# 259        M8X         Etobicoke
# 264        M4Y  Downtown Toronto
# 267        M7Y      East Toronto
# 268        M8Y         Etobicoke
# 269        M8Y         Etobicoke
# 270        M8Y         Etobicoke
# 271        M8Y         Etobicoke
# 272        M8Y         Etobicoke
# 273        M8Y         Etobicoke
# 274        M8Y         Etobicoke
# 275        M8Y         Etobicoke
# 284        M8Z         Etobicoke
# 285        M8Z         Etobicoke
# 286        M8Z         Etobicoke
# 287        M8Z         Etobicoke
# 288        M8Z         Etobicoke
#
#                                           Neighborhood
# 3                                            Parkwoods
# 4                                     Victoria Village
# 5                                         Harbourfront
# 6                                          Regent Park
# 7                                     Lawrence Heights
# 8                                       Lawrence Manor
# 9                                         Queen's Park
# 11                                    Islington Avenue
# 12                                               Rouge
# 13                                             Malvern
# 15                                     Don Mills North
# 16                                    Woodbine Gardens
# 17                                       Parkview Hill
# 18                                             Ryerson
# 19                                     Garden District
# 20                                           Glencairn
# 23                                          Cloverdale
# 24                                           Islington
# 25                                        Martin Grove
# 26                                    Princess Gardens
# 27                                     West Deane Park
# 28                                      Highland Creek
# 29                                          Rouge Hill
# 30                                          Port Union
# 32                                     Flemingdon Park
# 33                                     Don Mills South
# 34                                    Woodbine Heights
# 35                                      St. James Town
# 36                                  Humewood-Cedarvale
# 39                                   Bloordale Gardens
# ..                                                 ...
# 237                                    L'Amoreaux West
# 238                                       Steeles West
# 241                                           Rosedale
# 242                    Stn A PO Boxes 25 The Esplanade
# 245                                          Alderwood
# 246                                        Long Branch
# 247                                          Northwest
# 248                                        Upper Rouge
# 251                                        Cabbagetown
# 252                                     St. James Town
# 253                               First Canadian Place
# 254                                   Underground city
# 257                                       The Kingsway
# 258                                    Montgomery Road
# 259                                     Old Mill North
# 264                               Church and Wellesley
# 267  Business Reply Mail Processing Centre 969 Eastern
# 268                                         Humber Bay
# 269                                   King's Mill Park
# 270                           Kingsway Park South East
# 271                                          Mimico NE
# 272                                     Old Mill South
# 273                                 The Queensway East
# 274                              Royal York South East
# 275                                           Sunnylea
# 284                           Kingsway Park South West
# 285                                          Mimico NW
# 286                                 The Queensway West
# 287                              Royal York South West
# 288                                     South of Bloor
#
# [212 rows x 3 columns]

# %% [markdown]
# ## More than one neighborhood can exist in one postal code area.Rows will be combined into one row with the neighborhoods separated with a comma

# %%
#concat neighborhood
zipCodeDF_combined = zipCodeDF_borough.groupby(['PostalCode', 'Borough'])['Neighborhood'].apply(lambda x: "%s" % ', '.join(x))
#convert into dataframe
zipCodeDF_combined = zipCodeDF_combined.to_frame().reset_index()
zipCodeDF_combined
# Out:
#     PostalCode           Borough  \
# 0          M1B       Scarborough
# 1          M1C       Scarborough
# 2          M1E       Scarborough
# 3          M1G       Scarborough
# 4          M1H       Scarborough
# 5          M1J       Scarborough
# 6          M1K       Scarborough
# 7          M1L       Scarborough
# 8          M1M       Scarborough
# 9          M1N       Scarborough
# 10         M1P       Scarborough
# 11         M1R       Scarborough
# 12         M1S       Scarborough
# 13         M1T       Scarborough
# 14         M1V       Scarborough
# 15         M1W       Scarborough
# 16         M1X       Scarborough
# 17         M2H        North York
# 18         M2J        North York
# 19         M2K        North York
# 20         M2L        North York
# 21         M2M        North York
# 22         M2N        North York
# 23         M2P        North York
# 24         M2R        North York
# 25         M3A        North York
# 26         M3B        North York
# 27         M3C        North York
# 28         M3H        North York
# 29         M3J        North York
# ..         ...               ...
# 73         M6C              York
# 74         M6E              York
# 75         M6G  Downtown Toronto
# 76         M6H      West Toronto
# 77         M6J      West Toronto
# 78         M6K      West Toronto
# 79         M6L        North York
# 80         M6M              York
# 81         M6N              York
# 82         M6P      West Toronto
# 83         M6R      West Toronto
# 84         M6S      West Toronto
# 85         M7A      Queen's Park
# 86         M7R       Mississauga
# 87         M7Y      East Toronto
# 88         M8V         Etobicoke
# 89         M8W         Etobicoke
# 90         M8X         Etobicoke
# 91         M8Y         Etobicoke
# 92         M8Z         Etobicoke
# 93         M9A         Etobicoke
# 94         M9B         Etobicoke
# 95         M9C         Etobicoke
# 96         M9L        North York
# 97         M9M        North York
# 98         M9N              York
# 99         M9P         Etobicoke
# 100        M9R         Etobicoke
# 101        M9V         Etobicoke
# 102        M9W         Etobicoke
#
#                                           Neighborhood
# 0                                       Rouge, Malvern
# 1               Highland Creek, Rouge Hill, Port Union
# 2                    Guildwood, Morningside, West Hill
# 3                                               Woburn
# 4                                            Cedarbrae
# 5                                  Scarborough Village
# 6          East Birchmount Park, Ionview, Kennedy Park
# 7                      Clairlea, Golden Mile, Oakridge
# 8      Cliffcrest, Cliffside, Scarborough Village West
# 9                          Birch Cliff, Cliffside West
# 10   Dorset Park, Scarborough Town Centre, Wexford ...
# 11                                   Maryvale, Wexford
# 12                                           Agincourt
# 13             Clarks Corners, Sullivan, Tam O'Shanter
# 14   Agincourt North, L'Amoreaux East, Milliken, St...
# 15                       L'Amoreaux West, Steeles West
# 16                                         Upper Rouge
# 17                                   Hillcrest Village
# 18                        Fairview, Henry Farm, Oriole
# 19                                     Bayview Village
# 20                            Silver Hills, York Mills
# 21                             Newtonbrook, Willowdale
# 22                                    Willowdale South
# 23                                     York Mills West
# 24                                     Willowdale West
# 25                                           Parkwoods
# 26                                     Don Mills North
# 27                    Flemingdon Park, Don Mills South
# 28     Bathurst Manor, Downsview North, Wilson Heights
# 29                     Northwood Park, York University
# ..                                                 ...
# 73                                  Humewood-Cedarvale
# 74                                 Caledonia-Fairbanks
# 75                                            Christie
# 76                        Dovercourt Village, Dufferin
# 77                            Little Portugal, Trinity
# 78        Brockton, Exhibition Place, Parkdale Village
# 79            Maple Leaf Park, North Park, Upwood Park
# 80      Del Ray, Keelesdale, Mount Dennis, Silverthorn
# 81                       The Junction North, Runnymede
# 82                       High Park, The Junction South
# 83                              Parkdale, Roncesvalles
# 84                                  Runnymede, Swansea
# 85                                        Queen's Park
# 86               Canada Post Gateway Processing Centre
# 87   Business Reply Mail Processing Centre 969 Eastern
# 88        Humber Bay Shores, Mimico South, New Toronto
# 89                              Alderwood, Long Branch
# 90       The Kingsway, Montgomery Road, Old Mill North
# 91   Humber Bay, King's Mill Park, Kingsway Park So...
# 92   Kingsway Park South West, Mimico NW, The Queen...
# 93                                    Islington Avenue
# 94   Cloverdale, Islington, Martin Grove, Princess ...
# 95   Bloordale Gardens, Eringate, Markland Wood, Ol...
# 96                                       Humber Summit
# 97                                    Emery, Humberlea
# 98                                              Weston
# 99                                           Westmount
# 100  Kingsview Village, Martin Grove Gardens, Richv...
# 101  Albion Gardens, Beaumond Heights, Humbergate, ...
# 102                                          Northwest
#
# [103 rows x 3 columns]

# %% [markdown]
# ## print out the final DataFrame : using.shape() print the number of rows of your dataframe

# %%
zipCodeDF_combined.shape
# Out:
# (103, 3)

# %%
zipCodeDF_combined.shape[0]
# Out:
# 103

# %% [markdown]
# ## Get the geocode for each zip using file provide in the project

# %%
# !wget -q -O 'canada_geo.csv' http://cocl.us/Geospatial_data
print('Data downloaded!')
# Out:
# Data downloaded!

# %%
geocode = pd.read_csv('canada_geo.csv')
geocode
# Out:
#     Postal Code   Latitude  Longitude
# 0           M1B  43.806686 -79.194353
# 1           M1C  43.784535 -79.160497
# 2           M1E  43.763573 -79.188711
# 3           M1G  43.770992 -79.216917
# 4           M1H  43.773136 -79.239476
# 5           M1J  43.744734 -79.239476
# 6           M1K  43.727929 -79.262029
# 7           M1L  43.711112 -79.284577
# 8           M1M  43.716316 -79.239476
# 9           M1N  43.692657 -79.264848
# 10          M1P  43.757410 -79.273304
# 11          M1R  43.750072 -79.295849
# 12          M1S  43.794200 -79.262029
# 13          M1T  43.781638 -79.304302
# 14          M1V  43.815252 -79.284577
# 15          M1W  43.799525 -79.318389
# 16          M1X  43.836125 -79.205636
# 17          M2H  43.803762 -79.363452
# 18          M2J  43.778517 -79.346556
# 19          M2K  43.786947 -79.385975
# 20          M2L  43.757490 -79.374714
# 21          M2M  43.789053 -79.408493
# 22          M2N  43.770120 -79.408493
# 23          M2P  43.752758 -79.400049
# 24          M2R  43.782736 -79.442259
# 25          M3A  43.753259 -79.329656
# 26          M3B  43.745906 -79.352188
# 27          M3C  43.725900 -79.340923
# 28          M3H  43.754328 -79.442259
# 29          M3J  43.767980 -79.487262
# ..          ...        ...        ...
# 73          M6C  43.693781 -79.428191
# 74          M6E  43.689026 -79.453512
# 75          M6G  43.669542 -79.422564
# 76          M6H  43.669005 -79.442259
# 77          M6J  43.647927 -79.419750
# 78          M6K  43.636847 -79.428191
# 79          M6L  43.713756 -79.490074
# 80          M6M  43.691116 -79.476013
# 81          M6N  43.673185 -79.487262
# 82          M6P  43.661608 -79.464763
# 83          M6R  43.648960 -79.456325
# 84          M6S  43.651571 -79.484450
# 85          M7A  43.662301 -79.389494
# 86          M7R  43.636966 -79.615819
# 87          M7Y  43.662744 -79.321558
# 88          M8V  43.605647 -79.501321
# 89          M8W  43.602414 -79.543484
# 90          M8X  43.653654 -79.506944
# 91          M8Y  43.636258 -79.498509
# 92          M8Z  43.628841 -79.520999
# 93          M9A  43.667856 -79.532242
# 94          M9B  43.650943 -79.554724
# 95          M9C  43.643515 -79.577201
# 96          M9L  43.756303 -79.565963
# 97          M9M  43.724766 -79.532242
# 98          M9N  43.706876 -79.518188
# 99          M9P  43.696319 -79.532242
# 100         M9R  43.688905 -79.554724
# 101         M9V  43.739416 -79.588437
# 102         M9W  43.706748 -79.594054
#
# [103 rows x 3 columns]

# %% [markdown]
# ## Merge the lat and lon into the processing zip code data

# %%
zipCodeDF_geo = zipCodeDF_combined.set_index('PostalCode').join(geocode.set_index('Postal Code')).reset_index()
zipCodeDF_geo.shape
zipCodeDF_geo.columns = ['PostalCode', 'Borough', 'Neighborhood', 'Latitude', 'Longitude']
zipCodeDF_geo
# Out:
#     PostalCode           Borough  \
# 0          M1B       Scarborough
# 1          M1C       Scarborough
# 2          M1E       Scarborough
# 3          M1G       Scarborough
# 4          M1H       Scarborough
# 5          M1J       Scarborough
# 6          M1K       Scarborough
# 7          M1L       Scarborough
# 8          M1M       Scarborough
# 9          M1N       Scarborough
# 10         M1P       Scarborough
# 11         M1R       Scarborough
# 12         M1S       Scarborough
# 13         M1T       Scarborough
# 14         M1V       Scarborough
# 15         M1W       Scarborough
# 16         M1X       Scarborough
# 17         M2H        North York
# 18         M2J        North York
# 19         M2K        North York
# 20         M2L        North York
# 21         M2M        North York
# 22         M2N        North York
# 23         M2P        North York
# 24         M2R        North York
# 25         M3A        North York
# 26         M3B        North York
# 27         M3C        North York
# 28         M3H        North York
# 29         M3J        North York
# ..         ...               ...
# 73         M6C              York
# 74         M6E              York
# 75         M6G  Downtown Toronto
# 76         M6H      West Toronto
# 77         M6J      West Toronto
# 78         M6K      West Toronto
# 79         M6L        North York
# 80         M6M              York
# 81         M6N              York
# 82         M6P      West Toronto
# 83         M6R      West Toronto
# 84         M6S      West Toronto
# 85         M7A      Queen's Park
# 86         M7R       Mississauga
# 87         M7Y      East Toronto
# 88         M8V         Etobicoke
# 89         M8W         Etobicoke
# 90         M8X         Etobicoke
# 91         M8Y         Etobicoke
# 92         M8Z         Etobicoke
# 93         M9A         Etobicoke
# 94         M9B         Etobicoke
# 95         M9C         Etobicoke
# 96         M9L        North York
# 97         M9M        North York
# 98         M9N              York
# 99         M9P         Etobicoke
# 100        M9R         Etobicoke
# 101        M9V         Etobicoke
# 102        M9W         Etobicoke
#
#                                           Neighborhood   Latitude  Longitude
# 0                                       Rouge, Malvern  43.806686 -79.194353
# 1               Highland Creek, Rouge Hill, Port Union  43.784535 -79.160497
# 2                    Guildwood, Morningside, West Hill  43.763573 -79.188711
# 3                                               Woburn  43.770992 -79.216917
# 4                                            Cedarbrae  43.773136 -79.239476
# 5                                  Scarborough Village  43.744734 -79.239476
# 6          East Birchmount Park, Ionview, Kennedy Park  43.727929 -79.262029
# 7                      Clairlea, Golden Mile, Oakridge  43.711112 -79.284577
# 8      Cliffcrest, Cliffside, Scarborough Village West  43.716316 -79.239476
# 9                          Birch Cliff, Cliffside West  43.692657 -79.264848
# 10   Dorset Park, Scarborough Town Centre, Wexford ...  43.757410 -79.273304
# 11                                   Maryvale, Wexford  43.750072 -79.295849
# 12                                           Agincourt  43.794200 -79.262029
# 13             Clarks Corners, Sullivan, Tam O'Shanter  43.781638 -79.304302
# 14   Agincourt North, L'Amoreaux East, Milliken, St...  43.815252 -79.284577
# 15                       L'Amoreaux West, Steeles West  43.799525 -79.318389
# 16                                         Upper Rouge  43.836125 -79.205636
# 17                                   Hillcrest Village  43.803762 -79.363452
# 18                        Fairview, Henry Farm, Oriole  43.778517 -79.346556
# 19                                     Bayview Village  43.786947 -79.385975
# 20                            Silver Hills, York Mills  43.757490 -79.374714
# 21                             Newtonbrook, Willowdale  43.789053 -79.408493
# 22                                    Willowdale South  43.770120 -79.408493
# 23                                     York Mills West  43.752758 -79.400049
# 24                                     Willowdale West  43.782736 -79.442259
# 25                                           Parkwoods  43.753259 -79.329656
# 26                                     Don Mills North  43.745906 -79.352188
# 27                    Flemingdon Park, Don Mills South  43.725900 -79.340923
# 28     Bathurst Manor, Downsview North, Wilson Heights  43.754328 -79.442259
# 29                     Northwood Park, York University  43.767980 -79.487262
# ..                                                 ...        ...        ...
# 73                                  Humewood-Cedarvale  43.693781 -79.428191
# 74                                 Caledonia-Fairbanks  43.689026 -79.453512
# 75                                            Christie  43.669542 -79.422564
# 76                        Dovercourt Village, Dufferin  43.669005 -79.442259
# 77                            Little Portugal, Trinity  43.647927 -79.419750
# 78        Brockton, Exhibition Place, Parkdale Village  43.636847 -79.428191
# 79            Maple Leaf Park, North Park, Upwood Park  43.713756 -79.490074
# 80      Del Ray, Keelesdale, Mount Dennis, Silverthorn  43.691116 -79.476013
# 81                       The Junction North, Runnymede  43.673185 -79.487262
# 82                       High Park, The Junction South  43.661608 -79.464763
# 83                              Parkdale, Roncesvalles  43.648960 -79.456325
# 84                                  Runnymede, Swansea  43.651571 -79.484450
# 85                                        Queen's Park  43.662301 -79.389494
# 86               Canada Post Gateway Processing Centre  43.636966 -79.615819
# 87   Business Reply Mail Processing Centre 969 Eastern  43.662744 -79.321558
# 88        Humber Bay Shores, Mimico South, New Toronto  43.605647 -79.501321
# 89                              Alderwood, Long Branch  43.602414 -79.543484
# 90       The Kingsway, Montgomery Road, Old Mill North  43.653654 -79.506944
# 91   Humber Bay, King's Mill Park, Kingsway Park So...  43.636258 -79.498509
# 92   Kingsway Park South West, Mimico NW, The Queen...  43.628841 -79.520999
# 93                                    Islington Avenue  43.667856 -79.532242
# 94   Cloverdale, Islington, Martin Grove, Princess ...  43.650943 -79.554724
# 95   Bloordale Gardens, Eringate, Markland Wood, Ol...  43.643515 -79.577201
# 96                                       Humber Summit  43.756303 -79.565963
# 97                                    Emery, Humberlea  43.724766 -79.532242
# 98                                              Weston  43.706876 -79.518188
# 99                                           Westmount  43.696319 -79.532242
# 100  Kingsview Village, Martin Grove Gardens, Richv...  43.688905 -79.554724
# 101  Albion Gardens, Beaumond Heights, Humbergate, ...  43.739416 -79.588437
# 102                                          Northwest  43.706748 -79.594054
#
# [103 rows x 5 columns]

# %% [markdown]
# # Use geopy library to get the latitude and longitude values of toronto.

# %%
address = 'TORONTO, ON'

geolocator = Nominatim(user_agent="my-application")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print('The geograpical coordinate of Toronto are {}, {}.'.format(latitude, longitude))
# Out:
# The geograpical coordinate of Toronto are 43.653963, -79.387207.

# %% [markdown]
# # Create a map of Toronto with neighborhoods superimposed on top

# %%
# create map of New York using latitude and longitude values
map_toronto = folium.Map(location=[latitude, longitude], zoom_start=10)

# add markers to map
for lat, lng, borough, neighborhood in zip(zipCodeDF_geo['Latitude'], zipCodeDF_geo['Longitude'], zipCodeDF_geo['Borough'], zipCodeDF_geo['Neighborhood']):
    label = '{}, {}'.format(neighborhood, borough)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(map_toronto)  
    
map_toronto
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ##    ## Define FourSquare credential and version

# %%
# The code was removed by Watson Studio for sharing.

# %% [markdown]
# ## Using a neighbourhood to explore the foursquare API

# %%
## record 93 is a neighbor does not have venues information from foursquare 
neighborhood_latitude = zipCodeDF_geo.loc[93, 'Latitude'] # neighborhood latitude value
neighborhood_longitude = zipCodeDF_geo.loc[93, 'Longitude'] # neighborhood longitude value

neighborhood_name = zipCodeDF_geo.loc[93, 'Neighborhood'] # neighborhood name

borough_name = zipCodeDF_geo.loc[93, 'Borough'] # Borough name

print('Latitude and longitude values of {} at {} are {}, {}.'.format(neighborhood_name,
                                                               borough_name,
                                                               neighborhood_latitude, 
                                                               neighborhood_longitude))
# Out:
# Latitude and longitude values of Islington Avenue at Etobicoke are 43.6678556, -79.53224240000002.

# %%
## record 101
neighborhood_latitude = zipCodeDF_geo.loc[101, 'Latitude'] # neighborhood latitude value
neighborhood_longitude = zipCodeDF_geo.loc[101, 'Longitude'] # neighborhood longitude value

neighborhood_name = zipCodeDF_geo.loc[101, 'Neighborhood'] # neighborhood name

borough_name = zipCodeDF_geo.loc[101, 'Borough'] # Borough name

print('Latitude and longitude values of {} at {} are {}, {}.'.format(neighborhood_name,
                                                               borough_name,
                                                               neighborhood_latitude, 
                                                               neighborhood_longitude))
# Out:
# Latitude and longitude values of Albion Gardens, Beaumond Heights, Humbergate, Jamestown, Mount Olive, Silverstone, South Steeles, Thistletown at Etobicoke are 43.739416399999996, -79.5884369.

# %%
LIMIT = 100
radius = 500
url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
    CLIENT_ID, 
    CLIENT_SECRET, 
    VERSION, 
    neighborhood_latitude, 
    neighborhood_longitude, 
    radius, 
    LIMIT)
results = requests.get(url).json()
results
# Out:
# {'meta': {'code': 200, 'requestId': '5c3e66601ed2193f6b22cb5c'},
#  'response': {'groups': [{'items': [{'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4b04a05bf964a520c45522e3-0',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/food_grocery_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d118951735',
#          'name': 'Grocery Store',
#          'pluralName': 'Grocery Stores',
#          'primary': True,
#          'shortName': 'Grocery Store'}],
#        'id': '4b04a05bf964a520c45522e3',
#        'location': {'address': '1530 Albion Rd',
#         'cc': 'CA',
#         'city': 'Etobicoke',
#         'country': 'Canada',
#         'crossStreet': 'at Finch Ave. W.',
#         'distance': 318,
#         'formattedAddress': ['1530 Albion Rd (at Finch Ave. W.)',
#          'Etobicoke ON M9V 1B4',
#          'Canada'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.74196806166214,
#           'lng': -79.58663897240363}],
#         'lat': 43.74196806166214,
#         'lng': -79.58663897240363,
#         'postalCode': 'M9V 1B4',
#         'state': 'ON'},
#        'name': "Sheriff's No Frills",
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4c633939e1621b8d48842553-1',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/deli_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d1c5941735',
#          'name': 'Sandwich Place',
#          'pluralName': 'Sandwich Places',
#          'primary': True,
#          'shortName': 'Sandwiches'}],
#        'id': '4c633939e1621b8d48842553',
#        'location': {'address': '6210 Finch Ave. W Suite 103',
#         'cc': 'CA',
#         'city': 'Etobicoke',
#         'country': 'Canada',
#         'crossStreet': 'at Albion Rd.',
#         'distance': 344,
#         'formattedAddress': ['6210 Finch Ave. W Suite 103 (at Albion Rd.)',
#          'Etobicoke ON M9V 3Y5',
#          'Canada'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.742421428383224,
#           'lng': -79.58947097431394}],
#         'lat': 43.742421428383224,
#         'lng': -79.58947097431394,
#         'postalCode': 'M9V 3Y5',
#         'state': 'ON'},
#        'name': 'Subway',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4be70e26cf200f47e334153c-2',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/friedchicken_',
#           'suffix': '.png'},
#          'id': '4d4ae6fc7a7b7dea34424761',
#          'name': 'Fried Chicken Joint',
#          'pluralName': 'Fried Chicken Joints',
#          'primary': True,
#          'shortName': 'Fried Chicken'}],
#        'id': '4be70e26cf200f47e334153c',
#        'location': {'address': '1530 Albion Rd.',
#         'cc': 'CA',
#         'city': 'Etobicoke',
#         'country': 'Canada',
#         'crossStreet': 'at Kipling Ave. (Albion Centre)',
#         'distance': 370,
#         'formattedAddress': ['1530 Albion Rd. (at Kipling Ave. (Albion Centre))',
#          'Etobicoke ON M9V 1B4',
#          'Canada'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.74120165509377,
#           'lng': -79.58454469276013}],
#         'lat': 43.74120165509377,
#         'lng': -79.58454469276013,
#         'postalCode': 'M9V 1B4',
#         'state': 'ON'},
#        'name': 'Popeyes Louisiana Kitchen',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4be58dc4cf200f479154133c-3',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/pharmacy_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d10f951735',
#          'name': 'Pharmacy',
#          'pluralName': 'Pharmacies',
#          'primary': True,
#          'shortName': 'Pharmacy'}],
#        'id': '4be58dc4cf200f479154133c',
#        'location': {'address': '1530 Albion Rd',
#         'cc': 'CA',
#         'city': 'Etobicoke',
#         'country': 'Canada',
#         'crossStreet': 'Albion Mall',
#         'distance': 438,
#         'formattedAddress': ['1530 Albion Rd (Albion Mall)',
#          'Etobicoke ON M9V 1B4',
#          'Canada'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.74083239297218,
#           'lng': -79.58334731801473}],
#         'lat': 43.74083239297218,
#         'lng': -79.58334731801473,
#         'postalCode': 'M9V 1B4',
#         'state': 'ON'},
#        'name': 'Shoppers Drug Mart',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4cd4738cdfb4a1cd4337535c-4',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/beergarden_',
#           'suffix': '.png'},
#          'id': '5370f356bcbc57f1066c94c2',
#          'name': 'Beer Store',
#          'pluralName': 'Beer Stores',
#          'primary': True,
#          'shortName': 'Beer Store'}],
#        'id': '4cd4738cdfb4a1cd4337535c',
#        'location': {'address': '1530 Albion Rd',
#         'cc': 'CA',
#         'city': 'Etobicoke',
#         'country': 'Canada',
#         'crossStreet': 'Near Finch Ave. W.',
#         'distance': 413,
#         'formattedAddress': ['1530 Albion Rd (Near Finch Ave. W.)',
#          'Etobicoke ON M9V 1B4',
#          'Canada'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.7416936,
#           'lng': -79.5843728}],
#         'lat': 43.7416936,
#         'lng': -79.5843728,
#         'postalCode': 'M9V 1B4',
#         'state': 'ON'},
#        'name': 'The Beer Store',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4d8ba6910c4e41bdaaf7667f-5',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d1ca941735',
#          'name': 'Pizza Place',
#          'pluralName': 'Pizza Places',
#          'primary': True,
#          'shortName': 'Pizza'}],
#        'id': '4d8ba6910c4e41bdaaf7667f',
#        'location': {'address': '1530 Albion Road, Unit T25',
#         'cc': 'CA',
#         'city': 'Etobicoke',
#         'country': 'Canada',
#         'distance': 397,
#         'formattedAddress': ['1530 Albion Road, Unit T25',
#          'Etobicoke ON M9V 1B4',
#          'Canada'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.74156896801906,
#           'lng': -79.58448886871338}],
#         'lat': 43.74156896801906,
#         'lng': -79.58448886871338,
#         'postalCode': 'M9V 1B4',
#         'state': 'ON'},
#        'name': 'Pizza Pizza',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-5112b872e4b0c0a78d7bcd27-6',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/food_grocery_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d118951735',
#          'name': 'Grocery Store',
#          'pluralName': 'Grocery Stores',
#          'primary': True,
#          'shortName': 'Grocery Store'}],
#        'id': '5112b872e4b0c0a78d7bcd27',
#        'location': {'address': '1620 Albion road',
#         'cc': 'CA',
#         'city': 'Toronto',
#         'country': 'Canada',
#         'crossStreet': 'Albion Road and Finch Ave',
#         'distance': 319,
#         'formattedAddress': ['1620 Albion road (Albion Road and Finch Ave)',
#          'Toronto ON',
#          'Canada'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.74184023292111,
#           'lng': -79.59056069637506}],
#         'lat': 43.74184023292111,
#         'lng': -79.59056069637506,
#         'state': 'ON'},
#        'name': 'Sunny Foodmart',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4cd9d00734bb8cfa6576babf-7',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d1e0931735',
#          'name': 'Coffee Shop',
#          'pluralName': 'Coffee Shops',
#          'primary': True,
#          'shortName': 'Coffee Shop'}],
#        'id': '4cd9d00734bb8cfa6576babf',
#        'location': {'address': '6220 Finch Ave West',
#         'cc': 'CA',
#         'city': 'Etobicoke',
#         'country': 'Canada',
#         'crossStreet': 'Albion',
#         'distance': 306,
#         'formattedAddress': ['6220 Finch Ave West (Albion)',
#          'Etobicoke ON M9V 0A1',
#          'Canada'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.7420146612893,
#           'lng': -79.58968967199326}],
#         'lat': 43.7420146612893,
#         'lng': -79.58968967199326,
#         'postalCode': 'M9V 0A1',
#         'state': 'ON'},
#        'name': 'Tim Hortons',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4c1951d6834e2d7f2d3a2a80-8',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/fastfood_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d16e941735',
#          'name': 'Fast Food Restaurant',
#          'pluralName': 'Fast Food Restaurants',
#          'primary': True,
#          'shortName': 'Fast Food'}],
#        'id': '4c1951d6834e2d7f2d3a2a80',
#        'location': {'address': '1530 Albion Road',
#         'cc': 'CA',
#         'city': 'Toronto',
#         'country': 'Canada',
#         'distance': 404,
#         'formattedAddress': ['1530 Albion Road',
#          'Toronto ON M9V 1B4',
#          'Canada'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.74163461048035,
#           'lng': -79.58444567853267}],
#         'lat': 43.74163461048035,
#         'lng': -79.58444567853267,
#         'postalCode': 'M9V 1B4',
#         'state': 'ON'},
#        'name': "McDonald's",
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4ce971bff8653704e40db7c4-9',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/food_liquor_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d186941735',
#          'name': 'Liquor Store',
#          'pluralName': 'Liquor Stores',
#          'primary': True,
#          'shortName': 'Liquor Store'}],
#        'id': '4ce971bff8653704e40db7c4',
#        'location': {'address': 'Albion Mall',
#         'cc': 'CA',
#         'city': 'Toronto',
#         'country': 'Canada',
#         'crossStreet': '1530 Albion Rd',
#         'distance': 392,
#         'formattedAddress': ['Albion Mall (1530 Albion Rd)',
#          'Toronto ON M9V 1B4',
#          'Canada'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.741507521946716,
#           'lng': -79.58450113981092}],
#         'lat': 43.741507521946716,
#         'lng': -79.58450113981092,
#         'postalCode': 'M9V 1B4',
#         'state': 'ON'},
#        'name': 'LCBO',
#        'photos': {'count': 0, 'groups': []}}}],
#     'name': 'recommended',
#     'type': 'Recommended Places'}],
#   'headerFullLocation': 'Rexdale, Toronto',
#   'headerLocation': 'Rexdale',
#   'headerLocationGranularity': 'neighborhood',
#   'suggestedBounds': {'ne': {'lat': 43.7439164045, 'lng': -79.58222007762089},
#    'sw': {'lat': 43.734916395499994, 'lng': -79.59465372237912}},
#   'suggestedFilters': {'filters': [{'key': 'openNow', 'name': 'Open now'}],
#    'header': 'Tap to show:'},
#   'totalResults': 10}}

# %%
## get category as New York excerise
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

# %%
venues = results['response']['groups'][0]['items']
    
nearby_venues = json_normalize(venues) # flatten JSON

# filter columns
filtered_columns = ['venue.name', 'venue.categories', 'venue.location.lat', 'venue.location.lng']
nearby_venues =nearby_venues.loc[:, filtered_columns]

# filter the category for each row
nearby_venues['venue.categories'] = nearby_venues.apply(get_category_type, axis=1)

# clean columns
nearby_venues.columns = [col.split(".")[-1] for col in nearby_venues.columns]

nearby_venues.head()
# Out:
#                         name           categories        lat        lng
# 0        Sheriff's No Frills        Grocery Store  43.741968 -79.586639
# 1                     Subway       Sandwich Place  43.742421 -79.589471
# 2  Popeyes Louisiana Kitchen  Fried Chicken Joint  43.741202 -79.584545
# 3         Shoppers Drug Mart             Pharmacy  43.740832 -79.583347
# 4             The Beer Store           Beer Store  43.741694 -79.584373

# %%
print('{} venues were returned by Foursquare.'.format(nearby_venues.shape[0]))
# Out:
# 10 venues were returned by Foursquare.

# %%
def getNearbyVenues(names, latitudes, longitudes, radius=500):
    
    venues_list=[]
    for name, lat, lng in zip(names, latitudes, longitudes):
        print(name)
            
        # create the API request URL
        url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
            CLIENT_ID, 
            CLIENT_SECRET, 
            VERSION, 
            lat, 
            lng, 
            radius, 
            LIMIT)
            
        # make the GET request
        results = requests.get(url).json()["response"]['groups'][0]['items']
        
        # return only relevant information for each nearby venue
        venues_list.append([(
            name, 
            lat, 
            lng, 
            v['venue']['name'], 
            v['venue']['location']['lat'], 
            v['venue']['location']['lng'],  
            v['venue']['categories'][0]['name']) for v in results])

    nearby_venues = pd.DataFrame([item for venue_list in venues_list for item in venue_list])
    nearby_venues.columns = ['Neighborhood', 
                  'Neighborhood Latitude', 
                  'Neighborhood Longitude', 
                  'Venue', 
                  'Venue Latitude', 
                  'Venue Longitude', 
                  'Venue Category']
    
    return(nearby_venues)

# %%
## get one of the borough
Etobicoke_data =  zipCodeDF_geo[zipCodeDF_geo.Borough =='Etobicoke'].reset_index(drop=True)   
#Etobicoke_data =  zipCodeDF_geo[zipCodeDF_geo.Neighborhood =='Neighborhood'].reset_index(drop=True)   

Etobicoke_venues = getNearbyVenues(names=Etobicoke_data['Neighborhood'],
                                  latitudes=Etobicoke_data['Latitude'],
                                   longitudes=Etobicoke_data['Longitude']
                                )
Etobicoke_venues
# Out:
# Humber Bay Shores, Mimico South, New Toronto
# Alderwood, Long Branch
# The Kingsway, Montgomery Road, Old Mill North
# Humber Bay, King's Mill Park, Kingsway Park South East, Mimico NE, Old Mill South, The Queensway East, Royal York South East, Sunnylea
# Kingsway Park South West, Mimico NW, The Queensway West, Royal York South West, South of Bloor
# Islington Avenue
# Cloverdale, Islington, Martin Grove, Princess Gardens, West Deane Park
# Bloordale Gardens, Eringate, Markland Wood, Old Burnhamthorpe
# Westmount
# Kingsview Village, Martin Grove Gardens, Richview Gardens, St. Phillips
# Albion Gardens, Beaumond Heights, Humbergate, Jamestown, Mount Olive, Silverstone, South Steeles, Thistletown
# Northwest
#                                          Neighborhood  Neighborhood Latitude  \
# 0        Humber Bay Shores, Mimico South, New Toronto              43.605647
# 1        Humber Bay Shores, Mimico South, New Toronto              43.605647
# 2        Humber Bay Shores, Mimico South, New Toronto              43.605647
# 3        Humber Bay Shores, Mimico South, New Toronto              43.605647
# 4        Humber Bay Shores, Mimico South, New Toronto              43.605647
# 5        Humber Bay Shores, Mimico South, New Toronto              43.605647
# 6        Humber Bay Shores, Mimico South, New Toronto              43.605647
# 7        Humber Bay Shores, Mimico South, New Toronto              43.605647
# 8        Humber Bay Shores, Mimico South, New Toronto              43.605647
# 9        Humber Bay Shores, Mimico South, New Toronto              43.605647
# 10       Humber Bay Shores, Mimico South, New Toronto              43.605647
# 11       Humber Bay Shores, Mimico South, New Toronto              43.605647
# 12       Humber Bay Shores, Mimico South, New Toronto              43.605647
# 13       Humber Bay Shores, Mimico South, New Toronto              43.605647
# 14       Humber Bay Shores, Mimico South, New Toronto              43.605647
# 15                             Alderwood, Long Branch              43.602414
# 16                             Alderwood, Long Branch              43.602414
# 17                             Alderwood, Long Branch              43.602414
# 18                             Alderwood, Long Branch              43.602414
# 19                             Alderwood, Long Branch              43.602414
# 20                             Alderwood, Long Branch              43.602414
# 21                             Alderwood, Long Branch              43.602414
# 22                             Alderwood, Long Branch              43.602414
# 23                             Alderwood, Long Branch              43.602414
# 24                             Alderwood, Long Branch              43.602414
# 25      The Kingsway, Montgomery Road, Old Mill North              43.653654
# 26      The Kingsway, Montgomery Road, Old Mill North              43.653654
# 27      The Kingsway, Montgomery Road, Old Mill North              43.653654
# 28  Humber Bay, King's Mill Park, Kingsway Park So...              43.636258
# 29  Kingsway Park South West, Mimico NW, The Queen...              43.628841
# ..                                                ...                    ...
# 41  Cloverdale, Islington, Martin Grove, Princess ...              43.650943
# 42  Bloordale Gardens, Eringate, Markland Wood, Ol...              43.643515
# 43  Bloordale Gardens, Eringate, Markland Wood, Ol...              43.643515
# 44  Bloordale Gardens, Eringate, Markland Wood, Ol...              43.643515
# 45  Bloordale Gardens, Eringate, Markland Wood, Ol...              43.643515
# 46  Bloordale Gardens, Eringate, Markland Wood, Ol...              43.643515
# 47  Bloordale Gardens, Eringate, Markland Wood, Ol...              43.643515
# 48                                          Westmount              43.696319
# 49                                          Westmount              43.696319
# 50                                          Westmount              43.696319
# 51                                          Westmount              43.696319
# 52                                          Westmount              43.696319
# 53                                          Westmount              43.696319
# 54                                          Westmount              43.696319
# 55  Kingsview Village, Martin Grove Gardens, Richv...              43.688905
# 56  Kingsview Village, Martin Grove Gardens, Richv...              43.688905
# 57  Kingsview Village, Martin Grove Gardens, Richv...              43.688905
# 58  Kingsview Village, Martin Grove Gardens, Richv...              43.688905
# 59  Albion Gardens, Beaumond Heights, Humbergate, ...              43.739416
# 60  Albion Gardens, Beaumond Heights, Humbergate, ...              43.739416
# 61  Albion Gardens, Beaumond Heights, Humbergate, ...              43.739416
# 62  Albion Gardens, Beaumond Heights, Humbergate, ...              43.739416
# 63  Albion Gardens, Beaumond Heights, Humbergate, ...              43.739416
# 64  Albion Gardens, Beaumond Heights, Humbergate, ...              43.739416
# 65  Albion Gardens, Beaumond Heights, Humbergate, ...              43.739416
# 66  Albion Gardens, Beaumond Heights, Humbergate, ...              43.739416
# 67  Albion Gardens, Beaumond Heights, Humbergate, ...              43.739416
# 68  Albion Gardens, Beaumond Heights, Humbergate, ...              43.739416
# 69                                          Northwest              43.706748
# 70                                          Northwest              43.706748
#
#     Neighborhood Longitude                                    Venue  \
# 0               -79.501321                                     LCBO
# 1               -79.501321                 New Toronto Fish & Chips
# 2               -79.501321                  Delicia Bakery & Pastry
# 3               -79.501321                    Lucky Dice Restaurant
# 4               -79.501321                               McDonald's
# 5               -79.501321                                   Subway
# 6               -79.501321                Popeyes Louisiana Kitchen
# 7               -79.501321                       Shoppers Drug Mart
# 8               -79.501321                         Maple Leaf House
# 9               -79.501321        Halibut House Fish and Chips Inc.
# 10              -79.501321                             Sense Appeal
# 11              -79.501321                           Domino's Pizza
# 12              -79.501321                       Crossfit Colosseum
# 13              -79.501321                  Lakeshore Village Fruit
# 14              -79.501321                                  Hex-Mex
# 15              -79.543484         Il Paesano Pizzeria & Restaurant
# 16              -79.543484                            Timothy's Pub
# 17              -79.543484         Toronto Gymnastics International
# 18              -79.543484                              Tim Hortons
# 19              -79.543484                                   Subway
# 20              -79.543484                              Pizza Pizza
# 21              -79.543484  T.Shevchenko Ukrainian Community Centre
# 22              -79.543484                                   Rexall
# 23              -79.543484                           Alderwood Pool
# 24              -79.543484                       Sir Adam Beck Rink
# 25              -79.506944            Lambton Kingsway Outdoor Pool
# 26              -79.506944                    Lambton-Kingsway Park
# 27              -79.506944                       Humber River Falls
# 28              -79.498509                            Woodford Park
# 29              -79.520999                         South St. Burger
# ..                     ...                                      ...
# 41              -79.554724                       Seaforth Golf Club
# 42              -79.577201                                     LCBO
# 43              -79.577201                           The Beer Store
# 44              -79.577201                       Shoppers Drug Mart
# 45              -79.577201                                Pizza Hut
# 46              -79.577201                           Cafe Sympatico
# 47              -79.577201                             Hasty Market
# 48              -79.532242                                Starbucks
# 49              -79.532242                   Mayflower Chinese Food
# 50              -79.532242                                Pizza Hut
# 51              -79.532242                                   Subway
# 52              -79.532242                               Pizza Nova
# 53              -79.532242                       Dixon & Royal York
# 54              -79.532242                           2 Bros Cuisine
# 55              -79.554724                             Wincott Park
# 56              -79.554724                       TTC Bus 45 Kipling
# 57              -79.554724                               Ital Pizza
# 58              -79.554724                                   Rogers
# 59              -79.588437                      Sheriff's No Frills
# 60              -79.588437                                   Subway
# 61              -79.588437                Popeyes Louisiana Kitchen
# 62              -79.588437                       Shoppers Drug Mart
# 63              -79.588437                           The Beer Store
# 64              -79.588437                              Pizza Pizza
# 65              -79.588437                           Sunny Foodmart
# 66              -79.588437                              Tim Hortons
# 67              -79.588437                               McDonald's
# 68              -79.588437                                     LCBO
# 69              -79.594054                       Economy Rent A Car
# 70              -79.594054                            Saand Rexdale
#
#     Venue Latitude  Venue Longitude             Venue Category
# 0        43.602281       -79.499302               Liquor Store
# 1        43.601849       -79.503281                 Restaurant
# 2        43.601403       -79.503012                     Bakery
# 3        43.601392       -79.503056                       Café
# 4        43.602470       -79.498963       Fast Food Restaurant
# 5        43.602382       -79.498275             Sandwich Place
# 6        43.602069       -79.499400        Fried Chicken Joint
# 7        43.601611       -79.502164                   Pharmacy
# 8        43.602040       -79.498678        American Restaurant
# 9        43.601960       -79.501147         Seafood Restaurant
# 10       43.601729       -79.501063                       Café
# 11       43.601676       -79.500908                Pizza Place
# 12       43.604816       -79.507024                        Gym
# 13       43.601258       -79.500489                Flower Shop
# 14       43.601261       -79.502284         Mexican Restaurant
# 15       43.601280       -79.545028                Pizza Place
# 16       43.600165       -79.544699                        Pub
# 17       43.599832       -79.542924                        Gym
# 18       43.602396       -79.545048                Coffee Shop
# 19       43.599262       -79.544340             Sandwich Place
# 20       43.605340       -79.547252                Pizza Place
# 21       43.602207       -79.543662               Dance Studio
# 22       43.602165       -79.545372                   Pharmacy
# 23       43.601802       -79.547247                       Pool
# 24       43.602526       -79.547455               Skating Rink
# 25       43.654821       -79.509231                       Pool
# 26       43.657085       -79.508145                       Park
# 27       43.655617       -79.501702                      River
# 28       43.633152       -79.496266             Baseball Field
# 29       43.631314       -79.518408               Burger Joint
# ..             ...              ...                        ...
# 41       43.651183       -79.556107                Golf Course
# 42       43.642099       -79.576592               Liquor Store
# 43       43.641313       -79.576925                 Beer Store
# 44       43.641646       -79.577362                   Pharmacy
# 45       43.641845       -79.576556                Pizza Place
# 46       43.641820       -79.576721                       Café
# 47       43.641871       -79.576370          Convenience Store
# 48       43.696249       -79.533117                Coffee Shop
# 49       43.692753       -79.531566         Chinese Restaurant
# 50       43.696431       -79.533233                Pizza Place
# 51       43.692927       -79.531471             Sandwich Place
# 52       43.692817       -79.531570                Pizza Place
# 53       43.699593       -79.534348               Intersection
# 54       43.692499       -79.531698  Middle Eastern Restaurant
# 55       43.689301       -79.551802                       Park
# 56       43.690907       -79.557066                   Bus Line
# 57       43.690136       -79.559979                Pizza Place
# 58       43.692620       -79.557402          Mobile Phone Shop
# 59       43.741968       -79.586639              Grocery Store
# 60       43.742421       -79.589471             Sandwich Place
# 61       43.741202       -79.584545        Fried Chicken Joint
# 62       43.740832       -79.583347                   Pharmacy
# 63       43.741694       -79.584373                 Beer Store
# 64       43.741569       -79.584489                Pizza Place
# 65       43.741840       -79.590561              Grocery Store
# 66       43.742015       -79.589690                Coffee Shop
# 67       43.741635       -79.584446       Fast Food Restaurant
# 68       43.741508       -79.584501               Liquor Store
# 69       43.708471       -79.589943        Rental Car Location
# 70       43.705072       -79.598725                  Drugstore
#
# [71 rows x 7 columns]

# %%
print(Etobicoke_venues.shape)
Etobicoke_venues.head()
# Out:
# (71, 7)
#                                    Neighborhood  Neighborhood Latitude  \
# 0  Humber Bay Shores, Mimico South, New Toronto              43.605647
# 1  Humber Bay Shores, Mimico South, New Toronto              43.605647
# 2  Humber Bay Shores, Mimico South, New Toronto              43.605647
# 3  Humber Bay Shores, Mimico South, New Toronto              43.605647
# 4  Humber Bay Shores, Mimico South, New Toronto              43.605647
#
#    Neighborhood Longitude                     Venue  Venue Latitude  \
# 0              -79.501321                      LCBO       43.602281
# 1              -79.501321  New Toronto Fish & Chips       43.601849
# 2              -79.501321   Delicia Bakery & Pastry       43.601403
# 3              -79.501321     Lucky Dice Restaurant       43.601392
# 4              -79.501321                McDonald's       43.602470
#
#    Venue Longitude        Venue Category
# 0       -79.499302          Liquor Store
# 1       -79.503281            Restaurant
# 2       -79.503012                Bakery
# 3       -79.503056                  Café
# 4       -79.498963  Fast Food Restaurant

# %%
# check how many neighborhood beling processed
Etobicoke_venues.groupby('Neighborhood').count().shape
# Out:
# (11, 6)

# %%
print('There are {} uniques categories.'.format(len(Etobicoke_venues['Venue Category'].unique())))
# Out:
# There are 39 uniques categories.

# %%
# one hot encoding
Etobicoke_venues.head()
Etobicoke_onehot = pd.get_dummies(Etobicoke_venues[['Venue Category']], prefix="", prefix_sep="")

# add neighborhood column back to dataframe
Etobicoke_onehot['Neighborhood'] = Etobicoke_venues['Neighborhood'] 

# move neighborhood column to the first column
fixed_columns = [Etobicoke_onehot.columns[-1]] + list(Etobicoke_onehot.columns[:-1])
Etobicoke_onehot = Etobicoke_onehot[fixed_columns]
Etobicoke_onehot.shape
# Out:
# (71, 40)

# %%
Etobicoke_grouped = Etobicoke_onehot.groupby('Neighborhood').mean().reset_index()
Etobicoke_grouped
#Etobicoke_data
# Out:
#                                          Neighborhood  American Restaurant  \
# 0   Albion Gardens, Beaumond Heights, Humbergate, ...             0.000000
# 1                              Alderwood, Long Branch             0.000000
# 2   Bloordale Gardens, Eringate, Markland Wood, Ol...             0.000000
# 3   Cloverdale, Islington, Martin Grove, Princess ...             0.000000
# 4        Humber Bay Shores, Mimico South, New Toronto             0.066667
# 5   Humber Bay, King's Mill Park, Kingsway Park So...             0.000000
# 6   Kingsview Village, Martin Grove Gardens, Richv...             0.000000
# 7   Kingsway Park South West, Mimico NW, The Queen...             0.000000
# 8                                           Northwest             0.000000
# 9       The Kingsway, Montgomery Road, Old Mill North             0.000000
# 10                                          Westmount             0.000000
#
#       Bakery  Bank  Baseball Field  Beer Store  Burger Joint  Bus Line  \
# 0   0.000000   0.0             0.0    0.100000      0.000000      0.00
# 1   0.000000   0.0             0.0    0.000000      0.000000      0.00
# 2   0.000000   0.0             0.0    0.166667      0.000000      0.00
# 3   0.000000   0.5             0.0    0.000000      0.000000      0.00
# 4   0.066667   0.0             0.0    0.000000      0.000000      0.00
# 5   0.000000   0.0             1.0    0.000000      0.000000      0.00
# 6   0.000000   0.0             0.0    0.000000      0.000000      0.25
# 7   0.090909   0.0             0.0    0.000000      0.090909      0.00
# 8   0.000000   0.0             0.0    0.000000      0.000000      0.00
# 9   0.000000   0.0             0.0    0.000000      0.000000      0.00
# 10  0.000000   0.0             0.0    0.000000      0.000000      0.00
#
#         Café  Chinese Restaurant     ...       Pub  Rental Car Location  \
# 0   0.000000            0.000000     ...       0.0                  0.0
# 1   0.000000            0.000000     ...       0.1                  0.0
# 2   0.166667            0.000000     ...       0.0                  0.0
# 3   0.000000            0.000000     ...       0.0                  0.0
# 4   0.133333            0.000000     ...       0.0                  0.0
# 5   0.000000            0.000000     ...       0.0                  0.0
# 6   0.000000            0.000000     ...       0.0                  0.0
# 7   0.000000            0.000000     ...       0.0                  0.0
# 8   0.000000            0.000000     ...       0.0                  0.5
# 9   0.000000            0.000000     ...       0.0                  0.0
# 10  0.000000            0.142857     ...       0.0                  0.0
#
#     Restaurant     River  Sandwich Place  Seafood Restaurant  Skating Rink  \
# 0     0.000000  0.000000        0.100000            0.000000           0.0
# 1     0.000000  0.000000        0.100000            0.000000           0.1
# 2     0.000000  0.000000        0.000000            0.000000           0.0
# 3     0.000000  0.000000        0.000000            0.000000           0.0
# 4     0.066667  0.000000        0.066667            0.066667           0.0
# 5     0.000000  0.000000        0.000000            0.000000           0.0
# 6     0.000000  0.000000        0.000000            0.000000           0.0
# 7     0.000000  0.000000        0.090909            0.000000           0.0
# 8     0.000000  0.000000        0.000000            0.000000           0.0
# 9     0.000000  0.333333        0.000000            0.000000           0.0
# 10    0.000000  0.000000        0.142857            0.000000           0.0
#
#     Social Club  Supplement Shop  Wings Joint
# 0      0.000000         0.000000     0.000000
# 1      0.000000         0.000000     0.000000
# 2      0.000000         0.000000     0.000000
# 3      0.000000         0.000000     0.000000
# 4      0.000000         0.000000     0.000000
# 5      0.000000         0.000000     0.000000
# 6      0.000000         0.000000     0.000000
# 7      0.090909         0.090909     0.090909
# 8      0.000000         0.000000     0.000000
# 9      0.000000         0.000000     0.000000
# 10     0.000000         0.000000     0.000000
#
# [11 rows x 40 columns]

# %%
## get the top 5 venues for each neighborhood
Etobicoke_grouped = Etobicoke_onehot.groupby('Neighborhood').mean().reset_index()
Etobicoke_grouped
#Etobicoke_data
# Out:
#                                          Neighborhood  American Restaurant  \
# 0   Albion Gardens, Beaumond Heights, Humbergate, ...             0.000000
# 1                              Alderwood, Long Branch             0.000000
# 2   Bloordale Gardens, Eringate, Markland Wood, Ol...             0.000000
# 3   Cloverdale, Islington, Martin Grove, Princess ...             0.000000
# 4        Humber Bay Shores, Mimico South, New Toronto             0.066667
# 5   Humber Bay, King's Mill Park, Kingsway Park So...             0.000000
# 6   Kingsview Village, Martin Grove Gardens, Richv...             0.000000
# 7   Kingsway Park South West, Mimico NW, The Queen...             0.000000
# 8                                           Northwest             0.000000
# 9       The Kingsway, Montgomery Road, Old Mill North             0.000000
# 10                                          Westmount             0.000000
#
#       Bakery  Bank  Baseball Field  Beer Store  Burger Joint  Bus Line  \
# 0   0.000000   0.0             0.0    0.100000      0.000000      0.00
# 1   0.000000   0.0             0.0    0.000000      0.000000      0.00
# 2   0.000000   0.0             0.0    0.166667      0.000000      0.00
# 3   0.000000   0.5             0.0    0.000000      0.000000      0.00
# 4   0.066667   0.0             0.0    0.000000      0.000000      0.00
# 5   0.000000   0.0             1.0    0.000000      0.000000      0.00
# 6   0.000000   0.0             0.0    0.000000      0.000000      0.25
# 7   0.090909   0.0             0.0    0.000000      0.090909      0.00
# 8   0.000000   0.0             0.0    0.000000      0.000000      0.00
# 9   0.000000   0.0             0.0    0.000000      0.000000      0.00
# 10  0.000000   0.0             0.0    0.000000      0.000000      0.00
#
#         Café  Chinese Restaurant     ...       Pub  Rental Car Location  \
# 0   0.000000            0.000000     ...       0.0                  0.0
# 1   0.000000            0.000000     ...       0.1                  0.0
# 2   0.166667            0.000000     ...       0.0                  0.0
# 3   0.000000            0.000000     ...       0.0                  0.0
# 4   0.133333            0.000000     ...       0.0                  0.0
# 5   0.000000            0.000000     ...       0.0                  0.0
# 6   0.000000            0.000000     ...       0.0                  0.0
# 7   0.000000            0.000000     ...       0.0                  0.0
# 8   0.000000            0.000000     ...       0.0                  0.5
# 9   0.000000            0.000000     ...       0.0                  0.0
# 10  0.000000            0.142857     ...       0.0                  0.0
#
#     Restaurant     River  Sandwich Place  Seafood Restaurant  Skating Rink  \
# 0     0.000000  0.000000        0.100000            0.000000           0.0
# 1     0.000000  0.000000        0.100000            0.000000           0.1
# 2     0.000000  0.000000        0.000000            0.000000           0.0
# 3     0.000000  0.000000        0.000000            0.000000           0.0
# 4     0.066667  0.000000        0.066667            0.066667           0.0
# 5     0.000000  0.000000        0.000000            0.000000           0.0
# 6     0.000000  0.000000        0.000000            0.000000           0.0
# 7     0.000000  0.000000        0.090909            0.000000           0.0
# 8     0.000000  0.000000        0.000000            0.000000           0.0
# 9     0.000000  0.333333        0.000000            0.000000           0.0
# 10    0.000000  0.000000        0.142857            0.000000           0.0
#
#     Social Club  Supplement Shop  Wings Joint
# 0      0.000000         0.000000     0.000000
# 1      0.000000         0.000000     0.000000
# 2      0.000000         0.000000     0.000000
# 3      0.000000         0.000000     0.000000
# 4      0.000000         0.000000     0.000000
# 5      0.000000         0.000000     0.000000
# 6      0.000000         0.000000     0.000000
# 7      0.090909         0.090909     0.090909
# 8      0.000000         0.000000     0.000000
# 9      0.000000         0.000000     0.000000
# 10     0.000000         0.000000     0.000000
#
# [11 rows x 40 columns]

# %%
## define a function to get the top N venues
def return_most_common_venues(row, num_top_venues):
    row_categories = row.iloc[1:]
    row_categories_sorted = row_categories.sort_values(ascending=False)
    
    return row_categories_sorted.index.values[0:num_top_venues]

# %%
num_top_venues = 10

indicators = ['st', 'nd', 'rd']

# create columns according to number of top venues
columns = ['Neighborhood']
for ind in np.arange(num_top_venues):
    try:
        columns.append('{}{} Most Common Venue'.format(ind+1, indicators[ind]))
    except:
        columns.append('{}th Most Common Venue'.format(ind+1))

# create a new dataframe
neighborhoods_venues_sorted = pd.DataFrame(columns=columns)
neighborhoods_venues_sorted['Neighborhood'] = Etobicoke_grouped['Neighborhood']

for ind in np.arange(Etobicoke_grouped.shape[0]):
    neighborhoods_venues_sorted.iloc[ind, 1:] = return_most_common_venues(Etobicoke_grouped.iloc[ind, :], num_top_venues)

neighborhoods_venues_sorted.shape
# Out:
# (11, 11)

# %%
## use Kmean clustering to cluster the neigborhood
# set number of clusters
kclusters = 5

Etobicoke_grouped_clustering = Etobicoke_grouped.drop('Neighborhood', 1)

# run k-means clustering
kmeans = KMeans(n_clusters=kclusters, random_state=0).fit(Etobicoke_grouped_clustering)

# check cluster labels generated for each row in the dataframe
kmeans.labels_
# Out:
# array([0, 0, 0, 3, 0, 1, 0, 0, 2, 4, 0], dtype=int32)

# %%
## append the cluster label with Etobicoke data
Etobicoke_merged = Etobicoke_data
# merge Etobicoke_grouped with Etobicoke_data to add latitude/longitude for each neighborhood
# one of the neighborhood does not have venues information, so using inner join will filter out those data
# another option is coded those no venues neighborhood into negative cluster

Etobicoke_merged = Etobicoke_merged.join(neighborhoods_venues_sorted.set_index('Neighborhood'), how = 'inner', on='Neighborhood')
# add clustering labels
Etobicoke_merged['Cluster Labels'] = kmeans.labels_
# add clustering labels
Etobicoke_merged # check the last columns!
# Out:
#    PostalCode    Borough                                       Neighborhood  \
# 0         M8V  Etobicoke       Humber Bay Shores, Mimico South, New Toronto
# 1         M8W  Etobicoke                             Alderwood, Long Branch
# 2         M8X  Etobicoke      The Kingsway, Montgomery Road, Old Mill North
# 3         M8Y  Etobicoke  Humber Bay, King's Mill Park, Kingsway Park So...
# 4         M8Z  Etobicoke  Kingsway Park South West, Mimico NW, The Queen...
# 6         M9B  Etobicoke  Cloverdale, Islington, Martin Grove, Princess ...
# 7         M9C  Etobicoke  Bloordale Gardens, Eringate, Markland Wood, Ol...
# 8         M9P  Etobicoke                                          Westmount
# 9         M9R  Etobicoke  Kingsview Village, Martin Grove Gardens, Richv...
# 10        M9V  Etobicoke  Albion Gardens, Beaumond Heights, Humbergate, ...
# 11        M9W  Etobicoke                                          Northwest
#
#      Latitude  Longitude 1st Most Common Venue 2nd Most Common Venue  \
# 0   43.605647 -79.501321                  Café                   Gym
# 1   43.602414 -79.543484           Pizza Place                   Pub
# 2   43.653654 -79.506944                  Pool                 River
# 3   43.636258 -79.498509        Baseball Field           Wings Joint
# 4   43.628841 -79.520999           Wings Joint       Supplement Shop
# 6   43.650943 -79.554724           Golf Course                  Bank
# 7   43.643515 -79.577201              Pharmacy          Liquor Store
# 8   43.696319 -79.532242           Pizza Place    Chinese Restaurant
# 9   43.688905 -79.554724           Pizza Place              Bus Line
# 10  43.739416 -79.588437         Grocery Store           Pizza Place
# 11  43.706748 -79.594054             Drugstore   Rental Car Location
#
#    3rd Most Common Venue 4th Most Common Venue      5th Most Common Venue  \
# 0            Pizza Place                Bakery       Fast Food Restaurant
# 1           Dance Studio           Coffee Shop                   Pharmacy
# 2                   Park    Chinese Restaurant                Flower Shop
# 3            Coffee Shop   Fried Chicken Joint                Flower Shop
# 4                 Bakery          Burger Joint          Convenience Store
# 6            Coffee Shop   Fried Chicken Joint                Flower Shop
# 7             Beer Store                  Café          Convenience Store
# 8           Intersection        Sandwich Place  Middle Eastern Restaurant
# 9      Mobile Phone Shop                  Park                Wings Joint
# 10           Coffee Shop  Fast Food Restaurant             Sandwich Place
# 11           Wings Joint           Coffee Shop        Fried Chicken Joint
#
#    6th Most Common Venue 7th Most Common Venue 8th Most Common Venue  \
# 0            Flower Shop   Fried Chicken Joint          Liquor Store
# 1                   Pool                   Gym        Sandwich Place
# 2   Fast Food Restaurant             Drugstore        Discount Store
# 3   Fast Food Restaurant             Drugstore        Discount Store
# 4         Discount Store  Fast Food Restaurant         Grocery Store
# 6   Fast Food Restaurant             Drugstore        Discount Store
# 7            Pizza Place           Wings Joint           Flower Shop
# 8            Coffee Shop  Fast Food Restaurant             Drugstore
# 9            Flower Shop  Fast Food Restaurant             Drugstore
# 10            Beer Store          Liquor Store   Fried Chicken Joint
# 11           Flower Shop  Fast Food Restaurant        Discount Store
#
#    9th Most Common Venue 10th Most Common Venue  Cluster Labels
# 0     Mexican Restaurant               Pharmacy               0
# 1           Skating Rink             Beer Store               0
# 2           Dance Studio      Convenience Store               0
# 3           Dance Studio      Convenience Store               3
# 4                    Gym            Social Club               0
# 6           Dance Studio      Convenience Store               1
# 7   Fast Food Restaurant              Drugstore               0
# 8         Discount Store           Dance Studio               0
# 9         Discount Store           Dance Studio               2
# 10              Pharmacy              Drugstore               4
# 11          Dance Studio      Convenience Store               0

# %%
## display the labeled data in map
# create map
map_clusters = folium.Map(location=[latitude, longitude], zoom_start=11)
# set color scheme for the clusters
x = np.arange(kclusters)
ys = [i+x+(i*x)**2 for i in range(kclusters)]
colors_array = cm.rainbow(np.linspace(0, 1, len(ys)))
rainbow = [colors.rgb2hex(i) for i in colors_array]

# add markers to the map
markers_colors = []
for lat, lon, poi, cluster in zip(Etobicoke_merged['Latitude'], Etobicoke_merged['Longitude'], 
                                  Etobicoke_merged['Neighborhood'], Etobicoke_merged['Cluster Labels']):
    label = folium.Popup(str(poi) + ' Cluster ' + str(cluster), parse_html=True)
    folium.CircleMarker(
        [lat, lon],
        radius=5,
        popup=label,
        color=rainbow[cluster-1],
        fill=True,
        fill_color=rainbow[cluster-1],
        fill_opacity=0.7).add_to(map_clusters)
       
map_clusters
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
